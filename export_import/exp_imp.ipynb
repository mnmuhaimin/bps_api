# %%
import pandas as pd
import numpy as np
import requests
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

warnings.filterwarnings('ignore')
api_key = '4eda5e3af511b6d4892332948b84476c'

# %% [markdown]
# ## 196

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(196, api_key)
data_196 = requests.get(url).json()
vervar_df = pd.DataFrame(data_196['vervar'])
turvar_df = pd.DataFrame(data_196['turvar'])
tahun_df = pd.DataFrame(data_196['tahun'])
content_df = pd.DataFrame(data={'id': data_196['datacontent'].keys(), 'values': data_196['datacontent'].values()})

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0:4].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['id'].str[-4:-1].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-1].astype('int64'), right_on = 'val') 

data_196_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_196_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_196_df['data_title'] =  data_196['var'][0]['label']

data_196_df.to_csv('expimp_196.csv', index=False)

# %% [markdown]
# ## 203

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(203, api_key)
data_203 = requests.get(url).json()
vervar_df = pd.DataFrame(data_203['vervar'])
turvar_df = pd.DataFrame(data_203['turvar'])
tahun_df = pd.DataFrame(data_203['tahun'])
content_df = pd.DataFrame(data={'id': data_203['datacontent'].keys(), 'values': data_203['datacontent'].values()})

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['id'].str[-3:-1].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-6:-3].astype('int64'), right_on = 'val') 

data_203_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_203_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_203_df['data_title'] =  data_203['var'][0]['label']

data_203_df.to_csv('expimp_203.csv', index=False)

# %% [markdown]
# ## 204

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(204, api_key)
data_204 = requests.get(url).json()
vervar_df = pd.DataFrame(data_204['vervar'])
turvar_df = pd.DataFrame(data_204['turvar'])
tahun_df = pd.DataFrame(data_204['tahun'])
content_df = pd.DataFrame(data={'id': data_204['datacontent'].keys(), 'values': data_204['datacontent'].values()})

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['id'].str[-3:-1].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-6:-3].astype('int64'), right_on = 'val') 

data_204_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_204_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_204_df['data_title'] =  data_204['var'][0]['label']

data_204_df.to_csv('expimp_204.csv', index=False)

# %% [markdown]
# ## 336

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(336, api_key)
data_336 = requests.get(url).json()
vervar_df = pd.DataFrame(data_336['vervar'])
turvar_df = pd.DataFrame(data_336['turvar'])
tahun_df = pd.DataFrame(data_336['tahun'])
content_df = pd.DataFrame(data={'id': data_336['datacontent'].keys(), 'values': data_336['datacontent'].values()})

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['id'].str[-4:-1].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-7:-4].astype('int64'), right_on = 'val') 

data_336_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_336_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_336_df['data_title'] =  data_336['var'][0]['label']

data_336_df.to_csv('expimp_336.csv', index=False)

# %% [markdown]
# ## 497

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(497, api_key)
data_497 = requests.get(url).json()
vervar_df = pd.DataFrame(data_497['vervar'])
turvar_df = pd.DataFrame(data_497['turvar'])
tahun_df = pd.DataFrame(data_497['tahun'])
content_df = pd.DataFrame(data={'id': data_497['datacontent'].keys(), 'values': data_497['datacontent'].values()})

content_df['tahun_adj'] = None
content_df.loc[content_df['id'].str.len() == 12, 'tahun_adj'] = content_df['id'].str[-4:-1]
content_df.loc[content_df['id'].str.len() == 13, 'tahun_adj'] = content_df['id'].str[-5:-2]

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0:4].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['tahun_adj'].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-7:-4].astype('int64'), right_on = 'val') 

data_497_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_497_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_497_df['data_title'] =  data_497['var'][0]['label']

data_497_df.to_csv('expimp_497.csv', index=False)

# %% [markdown]
# ## 498

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(498, api_key)
data_498 = requests.get(url).json()
vervar_df = pd.DataFrame(data_498['vervar'])
turvar_df = pd.DataFrame(data_498['turvar'])
tahun_df = pd.DataFrame(data_498['tahun'])
content_df = pd.DataFrame(data={'id': data_498['datacontent'].keys(), 'values': data_498['datacontent'].values()})

content_df['tahun_adj'] = None
content_df.loc[content_df['id'].str.len() == 12, 'tahun_adj'] = content_df['id'].str[-4:-1]
content_df.loc[content_df['id'].str.len() == 13, 'tahun_adj'] = content_df['id'].str[-5:-2]

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0:4].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['tahun_adj'].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-7:-4].astype('int64'), right_on = 'val') 

data_498_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_498_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_498_df['data_title'] =  data_498['var'][0]['label']

data_498_df.to_csv('expimp_498.csv', index=False)

# %% [markdown]
# ## 719

# %%
url = 'https://webapi.bps.go.id/v1/api/list/model/data/domain/0000/var/{0}/key/{1}/'.format(719, api_key)
data_719 = requests.get(url).json()
vervar_df = pd.DataFrame(data_719['vervar'])
turtahun_df = pd.DataFrame(data_719['turtahun'])
tahun_df = pd.DataFrame(data_719['tahun'])
content_df = pd.DataFrame(data={'id': data_719['datacontent'].keys(), 'values': data_719['datacontent'].values()})

def id_len(id):
    len_id = len(id)
    return len_id

content_df['id_len'] = content_df['id'].apply(id_len)

content_df_1 = content_df.merge(vervar_df, how='left', left_on = content_df['id'].str[0:4].astype('int64'), right_on = 'val')
content_df_2 = content_df_1.merge(tahun_df, how='left', left_on = content_df_1['id'].str[-4:-1].astype('int64'), right_on = 'val') 
content_df_3 = content_df_2.merge(turvar_df, how='left', left_on = content_df_2['id'].str[-7:-4].astype('int64'), right_on = 'val') 

data_719_df = content_df_3[['id', 'values', 'label_x', 'label_y', 'label']]
data_719_df.columns = ['id', 'values', 'dimensi', 'tahun', 'label']

# %%
data_719
# Out:
# {'status': 'OK',
#  'data-availability': 'available',
#  'var': [{'val': 719,
#    'label': 'Indeks Unit Value Ekspor Bulanan menurut Kode SITC 3 Digit (2013=100)',
#    'unit': '',
#    'subj': 'Ekspor-Impor',
#    'def': '',
#    'decimal': '2',
#    'note': 'Tahun dasar 2013'}],
#  'turvar': [{'val': 0, 'label': 'Tidak Ada'}],
#  'labelvervar': 'Kode SITC 3 digit (2013=100)',
#  'vervar': [{'val': 1,
#    'label': '001 Live animals other than animals of division 03'},
#   {'val': 12,
#    'label': '012  Daging lainnya dan sisa daging yang dapat dimakan, segar, dingin atau beku (kecuali daging dan sisa daging yang tidak layak atau tidak cocok untuk konsumsi manusia)'},
#   {'val': 16,
#    'label': '016  Daging dan sisa daging yang dapat dimakan, asin, dalam air garam, kering atau diasap; tepung dan tepung kasar dari daging atau sisanya'},
#   {'val': 17,
#    'label': '017  Daging dan sisa daging yang dapat dimakan, diolah atau diawetkan, tidak dirinci'},
#   {'val': 22,
# ...

# %%
content_df.loc[content_df['id_len'] == 11]
# Out:
#                 id  values  id_len
# 93     12719011410  105.19      11
# 94     12719011411   97.49      11
# 95     12719011412  102.62      11
# 105    12719011510  100.33      11
# 106    12719011511  106.01      11
# ...            ...     ...     ...
# 18897  99971901205  118.34      11
# 18898  99971901206  115.39      11
# 18899  99971901207  125.28      11
# 18900  99971901208  148.86      11
# 18901  99971901209  155.43      11
#
# [12919 rows x 3 columns]

# %%
data_719_df.tail()
# Out:
#                  id  values dimensi tahun label
# 18900   99971901208  148.86     NaN  2020   NaN
# 18901   99971901209  155.43     NaN  2020   NaN
# 18902  999719012010  126.66     NaN   NaN   NaN
# 18903  999719012011  154.26     NaN   NaN   NaN
# 18904  999719012012  111.17     NaN   NaN   NaN

# %%
data_498_df['data_title'] =  data_498['var'][0]['label']

data_498_df.to_csv('expimp_498.csv', index=False)
